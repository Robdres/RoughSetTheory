# %%
while True:
    print("First loop")
    it = 0 
    while True:
        print("Second loop")
        it +=1 
        if(it%4==0):
            print("exit")
            break
# Out:
# First loop
# Second loop
# Second loop
# Second loop
# Second loop
# exit
# First loop
# Second loop
# Second loop
# Second loop
# Second loop
# exit
# First loop
# Second loop
# Second loop
# Second loop
# Second loop
# exit
# First loop
# Second loop
# Second loop
# Second loop
# Second loop
# exit
# First loop
# Second loop
# Second loop
# Second loop
# Second loop
# exit
# First loop
# Second loop
# Second loop
# Second loop
# Second loop
# exit
# First loop
# Second loop
# Second loop
# Second loop
# Second loop
# exit
# First loop
# Second loop
# Second loop
# Second loop
# Second loop
# exit
# First loop
# Second loop
# Second loop
# Second loop
# Second loop
# exit
# First loop
# Second loop
# Second loop
# Second loop
# Second loop
# exit
# First loop
# Second loop
# Second loop
# Second loop
# Second loop
# exit
# First loop
# Second loop
# Second loop
# Second loop
# Second loop
# exit
# First loop
# Second loop
# Second loop
# Second loop
# Second loop
# exit
# ...
